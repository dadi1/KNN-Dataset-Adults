# %%
#importando as bibliotecas que serão utilizadas

import pandas as pd
import sklearn 
import matplotlib.pyplot as plt

# %%
#Leitura dos dados de treinamento

train = pd.read_csv("/kaggle/input/adult-pmr3508/train_data.csv",
        sep=r'\s*,\s*',
        engine='python',
        na_values="?")

# %%
train.shape
# Out:
# (32560, 16)

# %%
train.head()
# Out:
#       Id  age     workclass  fnlwgt     education  education.num  \
# 0  16280   34       Private  204991  Some-college             10
# 1  16281   58     Local-gov  310085          10th              6
# 2  16282   25       Private  146117  Some-college             10
# 3  16283   24       Private  138938  Some-college             10
# 4  16284   57  Self-emp-inc  258883       HS-grad              9
#
#        marital.status         occupation   relationship   race     sex  \
# 0            Divorced    Exec-managerial      Own-child  White    Male
# 1  Married-civ-spouse   Transport-moving        Husband  White    Male
# 2       Never-married  Machine-op-inspct  Not-in-family  White    Male
# 3            Divorced       Adm-clerical  Not-in-family  White  Female
# 4  Married-civ-spouse   Transport-moving        Husband  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0             0             0              44  United-States  <=50K
# ...

# %%
train.columns
# Out:
# Index(['Id', 'age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
train.info
# Out:
# <bound method DataFrame.info of           Id  age     workclass  fnlwgt     education  education.num  \
# 0      16280   34       Private  204991  Some-college             10
# 1      16281   58     Local-gov  310085          10th              6
# 2      16282   25       Private  146117  Some-college             10
# 3      16283   24       Private  138938  Some-college             10
# 4      16284   57  Self-emp-inc  258883       HS-grad              9
# ...      ...  ...           ...     ...           ...            ...
# 32555  48835   42       Private  384236       Masters             14
# 32556  48836   23       Private  129042       HS-grad              9
# 32557  48837   30       Private  195488       HS-grad              9
# 32558  48838   18       Private   27620       HS-grad              9
# 32559  48839   47     Local-gov  203067     Bachelors             13
#
#            marital.status         occupation   relationship   race     sex  \
# ...

# %% [markdown]
# # Análise dos dados

# %%
#verificar correlação da renda com idade
filtrado = train[train['income'] == '>50K']

#montar o gráfico de correlação
correlacao_age = filtrado['age'].value_counts().sort_index()
plt.figure(figsize=(10,6))
correlacao_age.plot(kind='bar', color = 'green')
plt.show()

# %%
#verificar correlação de classe de trabalho
filtrado = train[train['income'] == '>50K']
correlacao_workclass = filtrado['workclass'].value_counts().sort_index()
plt.figure(figsize=(10,6))
correlacao_workclass.plot(kind = 'bar', color = 'red')
plt.show()

# %%
filtrado_reverso = train[train['income'] == '<=50K']
correlacao_workclass = filtrado_reverso['workclass'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_workclass.plot(kind = 'bar', color = 'red')
plt.show()

# %%
filtrado = train[train['income'] == '>50K']
correlacao_fnlwgt = filtrado['fnlwgt'].value_counts().sort_index()
plt.figure(figsize=(10,6))
correlacao_fnlwgt.plot(kind = 'bar', color = 'blue')
plt.show()

# %%
filtrado = train[train['income'] == '>50K']

correlacao_education = filtrado['education'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_education.plot(kind = 'bar', color = 'pink')
plt.show()

# %%
filtrado = train[train['income'] == '>50K']
correlacao_educantionum = filtrado['education.num'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_educantionum.plot(kind = 'bar', color = 'black')
plt.show()

# %%
filtrado = train[train['income'] == '>50K']
correlacao_status = filtrado['marital.status'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_status.plot(kind = 'bar', color = 'gray')
plt.show()

# %%
filtrado = train[train['income'] == '>50K']
correlacao_ocupation = filtrado['occupation'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_ocupation.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
filtrado_reverso = train[train['income'] == '<=50K']
correlacao_workclass = filtrado_reverso['occupation'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_workclass.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_relationship = filtrado['relationship'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_relationship.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_race = filtrado['race'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_race.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
filtrado_reverso = train[train['income'] == '<=50K']
correlacao_workclass = filtrado_reverso['race'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_workclass.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_sex = filtrado['sex'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_sex.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_gain = filtrado['capital.gain'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_gain.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_loss = filtrado['capital.loss'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_loss.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_hours = filtrado['hours.per.week'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_hours.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
correlacao_country = filtrado['native.country'].value_counts().sort_index()
plt.figure(figsize = (10,6))
correlacao_country.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %%
all_country = train['native.country'].value_counts().sort_index()
plt.figure(figsize = (10,6))
all_country.plot(kind = 'bar', color = 'skyblue')
plt.show()

# %% [markdown]
# ## Conclusão da Análise de dados:
# As *label* native country, fnlwgt e relationship não tem grande correlação, portanto não serão utlizados no treinamento.

# %% [markdown]
# ## Dados faltantes

# %%
faltantes = train.isnull().sum()
plt.figure(figsize = (10,6))
faltantes.plot(kind = 'bar', color = 'red')
plt.show()

# %% [markdown]
# Os dados faltantes estão em apenas 3 colunas. País nativo pela análise de dados não tem correlação então não será utilizado no Modelo.
# Classe de trabalho e Ocupação, por outro lado, tem grande importância para o modelo a ser utlizado, portanto os dados faltantes serão apagados do *data frame*

# %% [markdown]
# # Mudanças nos dados de teste
# ### Foram decididos:
# * Remover os dados faltantes
# * Remover as colunas: Id, Fnlwgt, Race, Relationship, occupation, Marital status e Native Country.
# * Transformar as variáveis categóricas em variáveis quantitativas.
# * Normalizar os dados quantitativos para previnir que números grandes possam atrapalhar no cálculo das distâncias.

# %%
#remoção das labels que não serão usadas
train = train.drop(['Id','fnlwgt' ,'relationship','native.country','race', 'marital.status', 'occupation'], axis=1)
train.head()
# Out:
#    age     workclass     education  education.num     sex  capital.gain  \
# 0   34       Private  Some-college             10    Male             0
# 1   58     Local-gov          10th              6    Male             0
# 2   25       Private  Some-college             10    Male             0
# 3   24       Private  Some-college             10  Female             0
# 4   57  Self-emp-inc       HS-grad              9    Male          5178
#
#    capital.loss  hours.per.week income
# 0             0              44  <=50K
# 1             0              40  <=50K
# 2             0              42  <=50K
# 3             0              40  <=50K
# 4             0              60   >50K

# %%
from sklearn.preprocessing import LabelEncoder
#separação dos trabalhso que tem renda e não possuem renda
sem_renda = ['Never-worked', 'Without-pay']
train['workclass'] = train['workclass'].apply(lambda x: '0' if x in sem_renda else '1')

#separação de educação
formado = ['Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate', 'Hs-Grad', 'Master', 'Prof-school', 'Some-college']
train['education'] = train['education'].apply(lambda x: '1' if x in formado else '0')

#separão por gênero
train['sex'] = train['sex'].apply(lambda x: '1' if x == 'Male' else '0')

train['income'] = train['income'].apply(lambda x: '1' if x == '>50K' else '0')

train.head()
# Out:
#    age workclass education  education.num sex  capital.gain  capital.loss  \
# 0   34         1         1             10   1             0             0
# 1   58         1         0              6   1             0             0
# 2   25         1         1             10   1             0             0
# 3   24         1         1             10   0             0             0
# 4   57         1         0              9   1          5178             0
#
#    hours.per.week income
# 0              44      0
# 1              40      0
# 2              42      0
# 3              40      0
# 4              60      1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   education       32560 non-null  object
#  3   education.num   32560 non-null  int64
#  4   sex             32560 non-null  object
#  5   capital.gain    32560 non-null  int64
#  6   capital.loss    32560 non-null  int64
#  7   hours.per.week  32560 non-null  int64
#  8   income          32560 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# # Preparação dos dados de treinamento

# %%
test = pd.read_csv("/kaggle/input/adult-pmr3508/test_data.csv",sep=r'\s*,\s*',engine='python', na_values="?")
test.head()
# Out:
#    Id  age     workclass  fnlwgt  education  education.num  \
# 0   0   25       Private  120596  Bachelors             13
# 1   1   64     State-gov  152537  Bachelors             13
# 2   2   31       Private  100135    Masters             14
# 3   3   45       Private  189123    HS-grad              9
# 4   4   64  Self-emp-inc  487751  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married     Prof-specialty  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced    Exec-managerial  Not-in-family  White  Female
# 3       Never-married  Machine-op-inspct      Own-child  White    Male
# 4  Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country
# 0             0             0              44  United-States
# ...

# %%
#remoção dos dados faltantes
test = test.dropna()
#salver os Id`s
ids = test['Id']
#remoção das colunas que não serão utilizadas
test = test.drop(['Id','fnlwgt' ,'relationship','native.country','race', 'marital.status', 'occupation'], axis=1)
test.head()
# Out:
#    age     workclass  education  education.num     sex  capital.gain  \
# 0   25       Private  Bachelors             13    Male             0
# 1   64     State-gov  Bachelors             13    Male             0
# 2   31       Private    Masters             14  Female             0
# 3   45       Private    HS-grad              9    Male             0
# 4   64  Self-emp-inc  Bachelors             13    Male             0
#
#    capital.loss  hours.per.week
# 0             0              44
# 1             0              45
# 2             0              40
# 3             0              40
# 4             0              50

# %%
#separação dos trabalhso que tem renda e não possuem renda
sem_renda = ['Never-worked', 'Without-pay']
test['workclass'] = test['workclass'].apply(lambda x: '0' if x in sem_renda else '1')

#separação de educação
formado = ['Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate', 'Hs-Grad', 'Master', 'Prof-school', 'Some-college']
test['education'] = test['education'].apply(lambda x: '1' if x in formado else '0')

#separão por gênero
test['sex'] = test['sex'].apply(lambda x: '1' if x == 'Male' else '0')

test.head()
# Out:
#    age workclass education  education.num sex  capital.gain  capital.loss  \
# 0   25         1         1             13   1             0             0
# 1   64         1         1             13   1             0             0
# 2   31         1         0             14   0             0             0
# 3   45         1         0              9   1             0             0
# 4   64         1         1             13   1             0             0
#
#    hours.per.week
# 0              44
# 1              45
# 2              40
# 3              40
# 4              50

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15059 entries, 0 to 16279
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             15059 non-null  int64
#  1   workclass       15059 non-null  object
#  2   education       15059 non-null  object
#  3   education.num   15059 non-null  int64
#  4   sex             15059 non-null  object
#  5   capital.gain    15059 non-null  int64
#  6   capital.loss    15059 non-null  int64
#  7   hours.per.week  15059 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# # Testo do Algorítimo

# %% [markdown]
# ### Criação dos vetores de treino

# %%
Xtrain = train.drop('income', axis = 1)
Ytrain = train['income']

Ytrain.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: income, dtype: object

# %% [markdown]
# ## Teste para escolha do Melhor K

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import numpy as np

krange = range(10,31)
best = 0
best_acc = 0
for k in krange:
  knn = KNeighborsClassifier(n_neighbors=k)
  scores = cross_val_score(knn, Xtrain, Ytrain, cv=10)
  media = np.mean(scores)
  print(f'K = {k}, Score = {media:.4f}')
  if(media > best_acc):
    best = k
    best_acc = media
# Out:
# K = 10, Score = 0.8391
# K = 11, Score = 0.8346
# K = 12, Score = 0.8388
# K = 13, Score = 0.8357
# K = 14, Score = 0.8375
# K = 15, Score = 0.8372
# K = 16, Score = 0.8391
# K = 17, Score = 0.8378
# K = 18, Score = 0.8393
# K = 19, Score = 0.8389
# K = 20, Score = 0.8389
# K = 21, Score = 0.8405
# K = 22, Score = 0.8407
# K = 23, Score = 0.8397
# K = 24, Score = 0.8396
# K = 25, Score = 0.8404
# K = 26, Score = 0.8397
# K = 27, Score = 0.8387
# K = 28, Score = 0.8396
# K = 29, Score = 0.8389
# K = 30, Score = 0.8390

# %% [markdown]
# ### A melhor média foi de 0.8407 com valor de K = 22

# %%
knn = KNeighborsClassifier(n_neighbors = 22)

# %% [markdown]
# ## Utilização do KNN

# %%
knn.fit(Xtrain, Ytrain)

output = knn.predict(test)

output
# Out:
# array(['0', '0', '0', ..., '0', '0', '1'], dtype=object)

# %% [markdown]
# ### Criar arquivo de submissão

# %%
predictions = pd.DataFrame(({'Id':ids, 'income':output}))


predictions['income'] = predictions['income'].apply(lambda x: '<=50K' if x == '0' else '>50K')

predictions
# Out:
#           Id income
# 0          0  <=50K
# 1          1  <=50K
# 2          2  <=50K
# 3          3  <=50K
# 4          4   >50K
# ...      ...    ...
# 16275  16275  <=50K
# 16276  16276  <=50K
# 16277  16277  <=50K
# 16278  16278  <=50K
# 16279  16279   >50K
#
# [15059 rows x 2 columns]

# %%
predictions.to_csv('submission.csv', index = False)
